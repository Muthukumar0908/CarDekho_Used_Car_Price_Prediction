# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv(r"C:\Users\ADMIN\Videos\career_fair\carDekho\dont_ordinalencoding_cardekho.csv")
df1=pd.read_csv(r"C:\Users\ADMIN\Videos\career_fair\carDekho\ml_cardekho.csv")
df3=pd.read_csv(r"C:\Users\ADMIN\Videos\career_fair\carDekho\cardekho.csv")

# %%
df3.columns
# Out:
# Index(['fuel_type', 'body_type', 'kilometer', 'transmission_type', 'owner_no',
#        'brand', 'model', 'model_year', 'price', 'registration_year',
#        'seats_count', 'RDO_no', 'car_engine_cc', 'mileage', 'color',
#        'gear_box', 'location', 'age'],
#       dtype='object')

# %%
model_one='Ambassador'
new_data=df3.groupby(['model','registration_year'])['price'].sum().reset_index()
kd=new_data[(new_data['model']== model_one)]
kd
fig=px.pie(kd,  kd['registration_year'], kd['price'],title="Sum of car price in year:")
fig.show()
# Out:
# <div>                            <div id="3761bbe3-91a0-40e2-9164-34e4ef398be1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3761bbe3-91a0-40e2-9164-34e4ef398be1")) {                    Plotly.newPlot(                        "3761bbe3-91a0-40e2-9164-34e4ef398be1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"registration_year=%{label}<br>price=%{value}<extra></extra>","labels":[1985,2013,2014],"legendgroup":"","name":"","showlegend":true,"values":[495000.0,100000.0,120000.0],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10, ...
#
# var gd = document.getElementById('3761bbe3-91a0-40e2-9164-34e4ef398be1');
# var x = new MutationObserv

# %%
model_one='Ambassador'
new_data=df3.groupby(['model']).head()
kd=new_data[(new_data['model']== model_one)]
kd
fig=px.bar(kd,  x=kd['color'], y=kd['price'],title="Body type highest price:")
fig.show()
# Out:
# <div>                            <div id="3d539828-ad2d-48a9-836e-75ce8aeec61f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d539828-ad2d-48a9-836e-75ce8aeec61f")) {                    Plotly.newPlot(                        "3d539828-ad2d-48a9-836e-75ce8aeec61f",                        [{"alignmentgroup":"True","hovertemplate":"color=%{x}<br>price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Blue","Yellow","Yellow"],"xaxis":"x","y":[495000.0,100000.0,120000.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar": ...

# %%
model_one='Ambassador'
new_data=df3.groupby(['model']).head()
# kd=new_data[(new_data['model']== model_one)]
kd
fig=px.scatter(new_data,  y=new_data['location'], x=new_data['price'],title="Body type highest price:")
fig.show()
# Out:
# <div>                            <div id="15838429-1ca1-486b-b6f0-92f533d376eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15838429-1ca1-486b-b6f0-92f533d376eb")) {                    Plotly.newPlot(                        "15838429-1ca1-486b-b6f0-92f533d376eb",                        [{"hovertemplate":"price=%{x}<br>location=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[400000.0,811000.0,585000.0,462000.0,790000.0,1900000.0,345000.0,1200000.0,960000.0,585000.0,690000.0,682000.0,825000.0,595000.0,690000.0,1350000.0,5595000.0,521000.0,1005000.0,775000.0,2200000.0,582000.0,1090000.0,457000.0,4900000.0,550000.0,570000.0,220000.00000000003,4145000.000000001,861000.0,1785000.0000000002,802999.9999999999,2565000.0,674000.0,349000.
,175000.0,175000.0,120000.0,375000.0,100000.0,225000.0,250000.0,270000.0,170000.0,350000.0,225000.0,250000.0,150000.0,235000.0,1275000.0,250000.0,140000.0,290000.0,125000.0,115000.0,150000.0,370000.0,1075000.0,100000.0,125000.0,385000.0,115000.0,125000.0,250000.0,1700000.0,300000.0,170000.0,100000.0,125000.0,225000.0,300000.0,200000.0,150000.0,300000.0,120000.0,265000.0,300000.0,170000.0,350000.0,180000.0,110000.0,250000.0,100000.0,450000.0,100000.0,120000.0,180000.0,225000.0,395000.0,300000.0,280000.0,100000.0,226000.0,240000.0,179000.0,477000.0,125000.0,125000.0,260000.0,150000.0,1200000.0,100000.0,190000.0,425000.0,125000.0,1350000.0,240000.0,750000.0,425000.0,160000.0,600000.0,450000.0,142000.0,450000.0,120000.0,100000.0,175000.0,400000.0,200000.0,115000.0,180000.0,155000.0,158000.0,165000.0,250000.0,350000.0,115000.0,120000.0,150000.0,375000.0,140000.0,290000.0,210000.0,130000.0,135000.0,150000.0,110000.0,250000.0,130000.0,225000.0,300000.0,135000.0,180000.0,249000.00000000003,249000.00000000003,300000.0,120000.0,200000.0,375000.0,260000.0,200000.0,220000.00000000003,250000.0,225000.0,161000.0,230000.0,215000.0,114000.0,310000.0,150000.0,220000.00000000003,280000.0,230000.0,265000.0,125000.0,280000.0,125000.0,225000.0,210000.0,205000.0,130000.0,165000.0,425000.0,225000.0,205000.0,205000.0,330000.0,170000.0,235000.0,250000.0,150000.0,445000.0,400000.0,180000.0,275000.0,167000.0,290000.0,250000.0,141000.0,271000.0,160000.0,390000.0,185000.0,180000.0,250000.0,365000.0,390000.0,250000.0,295000.0,140000.0,260000.0,117000.0,415000.00000000006,7900000.0,249000.00000000003,350000.0,165000.0,275000.0,380000.0,208000.0,250000.0,17 ...

# %%
old=df[['fuel_type', 'kilometer', 'transmission_type', 'owner_no', 'brand',
       'model', 'model_year', 'seats_count', 'car_engine_cc', 'mileage',
       'location', 'age']]

# %%
column1,column2 = st.columns([2,2], gap = 'small')
fuel_type = df['fuel_type'].unique()
min_kilometer = df['kilometer'].min()
max_kilometer = df['kilometer'].max()
transmission_type = df['transmission_type'].unique()
min_owner_no = df['owner_no']
brand= df['brand'].unique()
model = df['model'].unique()
min_model_year = df['model_year']
min_seats_count = df['seats_count'].min()
max_seats_count = df['seats_count'].max()
min_car_engine_cc = df['car_engine_cc'].min()
max_car_engine_cc = df['car_engine_cc'].max()
min_mileage = df['mileage'].min()
max_mileage = df['mileage'].max()
location = df['location'].unique()
age = df['age']

# %%
old.head(1)
# Out:
#   fuel_type  kilometer transmission_type  owner_no   brand           model  \
# 0    Petrol   0.000008            Manual         3  Maruti  Maruti Celerio
#
#    model_year  seats_count  car_engine_cc  mileage   location  age
# 0        2015            5            998     23.1  bengalore    8

# %%
df.columns
# Out:
# Index(['fuel_type', 'body_type', 'kilometer', 'transmission_type', 'owner_no',
#        'brand', 'model', 'model_year', 'price', 'registration_year',
#        'seats_count', 'car_engine_cc', 'mileage', 'color', 'location', 'age'],
#       dtype='object')

# %%
df.head(10)
# Out:
#   fuel_type  body_type  kilometer transmission_type  owner_no    brand  \
# 0    Petrol  Hatchback   0.000008            Manual         3   Maruti
# 1    Petrol        SUV   0.000031            Manual         2     Ford
# 2    Petrol  Hatchback   0.000084            Manual         1     Tata
# 3    Petrol      Sedan   0.000056            Manual         1  Hyundai
# 4    Diesel        SUV   0.000017            Manual         1   Maruti
# 5    Diesel        SUV   0.000050            Manual         1     Jeep
# 6    Petrol  Hatchback   0.000026            Manual         1   Datsun
# 7    Petrol        SUV   0.000033         Automatic         1  Hyundai
# 8    Petrol      Sedan   0.000027         Automatic         1   Maruti
# 9    Petrol  Hatchback   0.000084            Manual         1     Tata
#
#                 model  model_year      price  registration_year  seats_count  \
# 0      Maruti Celerio        2015   400000.0               2015            5
# 1       Ford Ecosport        2018   811000.0               2018            5
# 2          Tata Tiago        2018   585000.0               2018            5
# 3       Hyundai Xcent        2014   462000.0               2014            5
# 4  Maruti SX4 S Cross        2015   790000.0               2015            5
# 5        Jeep Compass        2020  1900000.0               2020            5
# 6           Datsun GO        2017   345000.0               2017            5
# 7       Hyundai Venue        2021  1200000.0               2021            5
# 8         Maruti Ciaz        2018   960000.0               2018            5
# 9          Tata Tiago        2017   585000.0               2018            5
#
#    car_engine_cc  mileage   color   location  age
# 0            998    23.10   White  bengalore    8
# 1           1497    17.00   White  bengalore    5
# 2           1199    23.84     Red  bengalore    5
# 3           1197    19.10  Others  bengalore    9
# 4           1248    23.65    Gray  bengalore    8
# 5           1956    17.10  Others  bengalore    3
# 6           1198    20.63    Grey  bengalore    6
# 7            998    18.15  Others  bengalore    2
# 8           1462    20.28  Maroon  bengalore    5
# 9           1199    23.84     Red  bengalore    5

# %%
for i in df.columns:
    if (df[i].dtype == 'object'):
        col_name = i
        decode = df[i].sort_values().unique() # status
        encode = df1[i].sort_values().unique() # 0,1,2
        globals()[col_name] = {}
        globals()[i] = dict(zip(decode, encode))

# %%
globals()['body_type']
# Out:
# {'Convertibles': 0.0,
#  'Coupe': 1.0,
#  'Hatchback': 2.0,
#  'Hybrids': 3.0,
#  'MUV': 4.0,
#  'Minivans': 5.0,
#  'Pickup Trucks': 6.0,
#  'SUV': 7.0,
#  'Sedan': 8.0,
#  'Wagon': 9.0,
#  nan: nan}

# %%
df3.head()
# Out:
#   fuel_type  body_type  kilometer transmission_type  owner_no    brand  \
# 0    Petrol  Hatchback     120000            Manual         3   Maruti
# 1    Petrol        SUV      32706            Manual         2     Ford
# 2    Petrol  Hatchback      11949            Manual         1     Tata
# 3    Petrol      Sedan      17794            Manual         1  Hyundai
# 4    Diesel        SUV      60000            Manual         1   Maruti
#
#                 model  model_year     price  registration_year  seats_count  \
# 0      Maruti Celerio        2015  400000.0               2015            5
# 1       Ford Ecosport        2018  811000.0               2018            5
# 2          Tata Tiago        2018  585000.0               2018            5
# 3       Hyundai Xcent        2014  462000.0               2014            5
# 4  Maruti SX4 S Cross        2015  790000.0               2015            5
#
#   RDO_no  car_engine_cc  mileage   color  gear_box   location  age
# 0   KA51            998    23.10   White         5  bengalore    8
# 1   KA05           1497    17.00   White         5  bengalore    5
# 2   KA03           1199    23.84     Red         5  bengalore    5
# 3   KA53           1197    19.10  Others         5  bengalore    9
# 4   KA04           1248    23.65    Gray         5  bengalore    8

# %%
data=df3.groupby(['registration_year']).sum(['price']).sort_values('registration_year')
data
fig = px.line(data, y='price', x=data.index,title="total price in year vize line plot")

fig.update_traces(line_color='#FEFCFB',line={'width':3})
fig.show()
# Out:
# <div>                            <div id="a374e312-c6c7-478f-b551-4fbfc796c4f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a374e312-c6c7-478f-b551-4fbfc796c4f4")) {                    Plotly.newPlot(                        "a374e312-c6c7-478f-b551-4fbfc796c4f4",                        [{"hovertemplate":"registration_year=%{x}<br>price=%{y}<extra></extra>","legendgroup":"","line":{"color":"#FEFCFB","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1985,1997,1999,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[655000.0,425000.0,100000.0,1684000.0,490000.0,1235000.0,1799000.0,2364000.0,6727000.0,9613000.0,21457000.0,34780000.0,126256000.0,139307000.0,175396000.0,215511000.0,366920000.0,359240000.0,627000000.0,858756000.0,1009700000.0,871530000.0,846492000.0,922309000.0,868431000.0,252206000.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewi ...

# %%
df3.head(1)
# Out:
#   fuel_type  body_type  kilometer transmission_type  owner_no   brand  \
# 0    Petrol  Hatchback     120000            Manual         3  Maruti
#
#             model  model_year     price  registration_year  seats_count  \
# 0  Maruti Celerio        2015  400000.0               2015            5
#
#   RDO_no  car_engine_cc  mileage  color  gear_box   location  age
# 0   KA51            998     23.1  White         5  bengalore    8

# %%
data=df.groupby(['year']).sum(['MarkDown']).sort_values("MarkDown")
data
fig = px.bar(data, y='MarkDown', x=data.index,title="total MarkDown in year",color=data.index)
fig.show()

# %%
data = df3.groupby(['brand'])['age'].max().reset_index()
fig=px.bar(data, x = data['brand'], y = data['age'],color =data['age'],title="maximum old car list using age:")
fig.show()
# Out:
# <div>                            <div id="e2f93d75-ee00-4faa-a7e6-d5fd9274c3b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2f93d75-ee00-4faa-a7e6-d5fd9274c3b7")) {                    Plotly.newPlot(                        "e2f93d75-ee00-4faa-a7e6-d5fd9274c3b7",                        [{"alignmentgroup":"True","hovertemplate":"brand=%{x}<br>age=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[14,17,18,2,9,16,20,38,24,20,7,12,6,4,12,7,4,22,16,10,38,22,10,21,13,10,11,18,19,22,14,13],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Audi","BMW","Chevrolet","Citroen","Datsun","Fiat","Ford","Hindustan Motors","Honda","Hyundai","Isuzu","Jaguar","Jeep","Kia","Land Rover","Lexus","MG","Mahindra","Mahindra Renault","Mahindra Ssangyong","Maruti","Mercedes-Benz","Mini","Mitsubishi","Nissan","Porsche","Renault","Skoda","Tata","Toyota","Volkswagen","Volvo"],"xaxis":"x","y":[14,17,18,2,9,16,20,38,24,20,7,12,6,4,12,7,4,22,16,10,38,22,10,21,13,10,11,18,19,22,14,13],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar ...

# %%
df3.head(1)
# Out:
#   fuel_type  body_type  kilometer transmission_type  owner_no   brand  \
# 0    Petrol  Hatchback     120000            Manual         3  Maruti
#
#             model  model_year     price  registration_year  seats_count  \
# 0  Maruti Celerio        2015  400000.0               2015            5
#
#   RDO_no  car_engine_cc  mileage  color  gear_box   location  age
# 0   KA51            998     23.1  White         5  bengalore    8

# %%
data = df3.groupby(['brand'])['seats_count'].max().reset_index()
data
fig=px.area(data, x = data['brand'], y = data['seats_count'],color =data['seats_count'],title="Hightst seat count cars list:")
fig.show()
# Out:
# <div>                            <div id="405e29d8-1248-4bf6-954f-52fd50d7f4f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("405e29d8-1248-4bf6-954f-52fd50d7f4f2")) {                    Plotly.newPlot(                        "405e29d8-1248-4bf6-954f-52fd50d7f4f2",                        [{"fillpattern":{"shape":""},"hovertemplate":"seats_count=%{y}<br>brand=%{x}<extra></extra>","legendgroup":"7","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"7","orientation":"v","showlegend":true,"stackgroup":"1","x":["Audi","BMW","Datsun","Ford","Isuzu","Jeep","Land Rover","MG","Mahindra Ssangyong","Mercedes-Benz","Mitsubishi","Skoda","Volvo"],"xaxis":"x","y":[7,7,7,7,7,7,7,7,7,7,7,7,7],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"seats_count=%{y}<br>brand=%{x}<extra></extra>","legendgroup":"8","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"8","orientation":"v","showlegend":true,"stackgroup":"1","x":["Chevrolet","Hyundai","Kia","Maruti","Renault","Tata","Toyota","Volkswagen"],"xaxis":"x","y":[8,8,8,8,8,8,8,8],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"seats_count=%{y}<br>brand=%{x}<extra></extra>","legendgroup":"5","line":{"color":"#00cc96"},"marker":{"symbol":"circle"},"mode":"lines","name":"5","orientation":"v","showlegend":true,"stackgroup":"1","x":["Citroen","Fiat","Jaguar","Lexus","Mahindra Renault","Mini","Porsche"],"xaxis":"x","y":[5,5,5,5,5,5,5],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"seats_count=%{y}<br>brand=%{x}<extra></extra>","legendgroup":"9","line":{"color":"#ab63fa"},"marker":{"symbol":"circle"},"mode":"lines","name":"9","orientation":"v","showlegend":true,"stackgroup":"1","x":["Hindustan Motors","Honda","Mahindra"],"xaxis":"x","y":[9,9,9],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"seats_count=%{y}<br>brand=%{x}<extra></extra>","legendgroup":"6","line":{"color":"#FFA15A"},"marker":{"symbol":"circle"},"mode":"lines","name":"6","orientation":"v","showlegend":true,"stackgroup":"1","x":["Nissan"],"xaxis":"x","y":[6],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888 ...

# %%
i=20
for i in range(4,8):
    pass
print(i)
# Out:
# 7
